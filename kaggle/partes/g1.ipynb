# %%
import pandas as pd
import plotly.express as px



df = pd.read_csv("https://raw.githubusercontent.com/IsaiasTy/salaries/main/salaries.csv") 
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2022               MI              FT  Machine Learning Engineer
# 1       2022               MI              FT  Machine Learning Engineer
# 2       2022               MI              FT             Data Scientist
# 3       2022               MI              FT             Data Scientist
# 4       2022               MI              FT             Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  130000             USD         130000                 US             0
# 1   90000             USD          90000                 US             0
# 2  120000             USD         120000                 US           100
# 3  100000             USD         100000                 US           100
# 4   85000             USD          85000                 US           100
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            M
# 4               US            M

# %%
lista_experiencia = df.experience_level.values.tolist()

lista_tamanho = df.company_size.values.tolist()

def contar(experiencia, tamanho, lista_experiencia, lista_tamanho):
    soma = 0
    for i in range(len(lista_tamanho)):
        if((lista_tamanho[i] == tamanho) and (lista_experiencia[i] == experiencia)):
            soma += 1
    return soma

experiencias = ['EN', 'MI', 'SE', 'EX']
tamanhos = ['L', 'M', 'S']
dt = pd.DataFrame(columns=['Experiencia', 'Tamanho', 'total'])

for tamanho in tamanhos:
    for experiencia in experiencias:
        valor = contar(tamanho, tipo, lista_experiencia, lista_tamanho)
        dt = pd.concat([dt, pd.DataFrame({'Experiencia': [experiencia], 'Tamanho': [tamanho], 
        'total': [valor]})], ignore_index=True)




dt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 23
#      18         valor = contar(tamanho, tipo, lista_experiencia, lista_tamanho)
#      19         dt = pd.concat([dt, pd.DataFrame({'Experiencia': [experiencia], 'Tamanho': [tamanho],
#      20         'total': [valor]})], ignore_index=True)
# ---> 23 px.bar(dt, x='total', y='Tipo', color ='Tamanho',orientation='h',
#      24 color_discrete_sequence=  px.colors.qualitative.Prism , template= 'plotly_dark',)
#      26 dt
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
#     367     height=None,
#     368 ) -> go.Figure:
#     369     """
#     370     In a bar plot, each row of `data_frame` is represented as a rectangular
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#     376         trace_patch=dict(textposition="auto"),
#     377         layout_patch=dict(barmode=barmode),
#     378     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['Experiencia', 'Tamanho', 'total'] but received: Tipo

# %%
lista_tamanho_empresa = df.company_size.values.tolist()

lista_salario_anual_dolar = df.salary_in_usd.values.tolist()

lista_tipo_emprego = df.employment_type.values.tolist()


def media_tam_emp(tamanho, tipo, lista_tamanho_empresa , lista_salario_anual_dolar, lista_tipo_emprego):
    count = 0
    soma = 0
    for i in range(len(lista_tamanho_empresa)):
        if((lista_tamanho_empresa[i] == tamanho) and (lista_tipo_emprego[i] == tipo)):
            soma += lista_salario_anual_dolar[i]
            count += 1
    return (soma // count)


tamanhos = ['L', 'M', 'S']
tipos = ['FT', 'PT', 'CT', 'FL']
dt = pd.DataFrame(columns=['Tamanho da Empresa', 'Tipo de Emprego', 'Salário em Dólar'])

for tamanho in tamanhos:
    for tipo in tipos:
        valores = media_tam_emp(tamanho, tipo, lista_tamanho_empresa, lista_salario_anual_dolar, lista_tipo_emprego)
        dt = pd.concat([dt, pd.DataFrame({'Tamanho da Empresa': [tamanho], 'Tipo de Emprego': [tipo], 
        'Salário em Dólar': [valores]})], ignore_index=True)



px.bar(dt, x='Salário em Dólar', y='Tamanho da Empresa', color ='Tipo de Emprego', barmode ='group' ,orientation='h', 
title = "Média salarial de acordo com o tipo de emprego e tamanho da empresa",
color_discrete_sequence=  px.colors.qualitative.Prism , template= 'plotly_dark',)
